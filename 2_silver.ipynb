# %% [markdown]
# ### Silver Table LookUps

# %%
dbutils.widgets.text("sourcefolder", 'netflix_directors')
dbutils.widgets.text("targetfolder", 'netflix_directors')

# %% [markdown]
# ### variables

# %%
var_src_folder = dbutils.widgets.get("sourcefolder")
var_tgt_folder = dbutils.widgets.get("targetfolder")

# %%
df = spark.read.format('csv')\
               .option('inferSchema', True)\
               .option('header', True)\
               .load(f'abfss://bronze@netflixstorageaccount.dfs.core.windows.net/{var_src_folder}')

# %%
df.display()

# %%
df.write.format('delta')\
        .mode('append')\
        .option('path', f'abfss://silver@netflixstorageaccount.dfs.core.windows.net/{var_tgt_folder}')\
        .save()
